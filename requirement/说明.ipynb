# %%
import torch
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
])

# %% [markdown]
# MNIST数据集包含60000个训练样本，10000个测试样本
# 同学们可以按照下述方式加载10000个测试样本或者自行下载数据集
# 每张28x28像素的图像，可以用一个784维的向量表示。
# 大家需要在此基础上根据期末大作业的要求，设计并完成实验。
# 在最后的期末报告中详细地说明使用的方法、原理、评估指标、实验结果等信息。

# %%
mnist_test = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
print(mnist_test)
# Out:
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            )

# %%
def visualize_mnist(dataset, num_images=10):
    fig, axes = plt.subplots(1, num_images, figsize=(num_images * 2, 2))
    for i in range(num_images):
        image, label = dataset[i]
        axes[i].imshow(image.squeeze(), cmap='gray')  
        axes[i].set_title(f"Label: {label}")
        axes[i].axis('off')
    plt.tight_layout()
    plt.show()


visualize_mnist(mnist_test, num_images=10)
